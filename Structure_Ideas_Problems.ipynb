# %% [markdown]
# # Prototyping the SMP_to_Stability model chain:
# ![grafik.png](attachment:a95fa0a3-a7a5-448f-84b1-8ea9d738e927.png)

# %% [markdown]
# # Structure, Problems and Ideas to solve:

# %% [markdown]
# ## STructure:
# 1. load pnt and process to layered caaml (layers, density, mean microparams)
# 2. class profile (computes, mechanical properties)
# 3. Funktions to compute mechanical models (weak layer given) + Iteration to find the weakest layer
#
# 4. visualization (this has to be discussed with CM
# 5. Embedding in automated workflow and AWSOME

# %% [markdown]
# ## Ideas:
# Varying num clusters --> dont miss a weak layer
#
# What about P_unstable? --> talk to stephie
